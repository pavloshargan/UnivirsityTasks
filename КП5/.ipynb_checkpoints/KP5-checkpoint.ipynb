# %% [markdown]
#  <h1 align="center" style="color:#4ca8ed">
#     Обробка та аналіз БМД.<br>
#     Группа: БС-81<br>
#     Мумінов А.O.<br>
#     Практикум Номер 5
# </h1>

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# <p style="color:#4ca8ed;font-size:150%">
#     1. Обрати реальні дані з kaggle або сгенерувати випадкові дані, що містять розподіл деякої ознаки в двох групах.
# </p>

# %%
database = pd.read_csv("HappinessAlcoholConsumption.csv")
database
# Out:
#          Country                           Region Hemisphere  HappinessScore  \
# 0        Denmark                   Western Europe      north           7.526
# 1    Switzerland                   Western Europe      north           7.509
# 2        Iceland                   Western Europe      north           7.501
# 3         Norway                   Western Europe      north           7.498
# 4        Finland                   Western Europe      north           7.413
# ..           ...                              ...        ...             ...
# 117     Tanzania               Sub-Saharan Africa      south           3.666
# 118      Liberia               Sub-Saharan Africa      north           3.622
# 119        Benin               Sub-Saharan Africa      north           3.484
# 120         Togo               Sub-Saharan Africa      north           3.303
# 121        Syria  Middle East and Northern Africa      north           3.069
#
#      HDI  GDP_PerCapita  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0    928         53.579             224                81             278
# 1    943         79.866             185               100             280
# 2    933         60.530             233                61              78
# 3    951         70.890             169                71             129
# 4    918         43.433             263               133              97
# ..   ...            ...             ...               ...             ...
# 117  533        878.000              36                 6               1
# 118  432        455.000              19               152               2
# 119  512        789.000              34                 4              13
# 120  500        577.000              36                 2              19
# 121  536          2.058               5                35              16
#
# [122 rows x 9 columns]

# %%
happiness_median = database['HappinessScore'].median()
database['IsHappy'] = [1 if x > happiness_median else 0 for x in database['HappinessScore']]

# %%
data = pd.DataFrame({
    'Dalc':database['Spirit_PerCapita'],      #Споживання алкоголя у будні. Градація іде по значенням 1 - дуже низьке,..., 5-дуже високе
    'IsHappy':database['IsHappy'] #Статус спільного сімейного проживання. {T - вместе, A - раздельно}
})

data
# Out:
#      Dalc  IsHappy
# 0      81        1
# 1     100        1
# 2      61        1
# 3      71        1
# 4     133        1
# ..    ...      ...
# 117     6        0
# 118   152        0
# 119     4        0
# 120     2        0
# 121    35        0
#
# [122 rows x 2 columns]

# %% [markdown]
# <p style="color:#4ca8ed;font-size:150%">
#     2. Побудувати графік, що відображає розподіл ознак в групах.
# </p>

# %%
g = sns.FacetGrid(data, col="Pstatus", height= 8)
g = g.map(plt.hist, "Dalc");

# %% [markdown]
# <p style="color:#4ca8ed;font-size:150%">
#    3. Написати функції, що оцінює зв'язок між ознакою та групою за критерієм Пірсона. Функція має оцінювати розбіжність на двох рівнях - 0,001 та 0,05, в залежністі від параметру significant_level, що передається в неї.
# </p>

# %%
def pirson_criterion(data,significant_level):
    print("-"*40)
    print("Робота функції")
    uniq1 = []           #Градация признака
    for i in data.iloc[:,0]:
        bl = True
        for j in uniq1:
            if(i == j):
                bl = False
        if(bl):
            uniq1.append(i)
            
    uniq2 = []           #Группы
    for i in data.iloc[:,1]:
        bl = True
        for j in uniq2:
            if(i == j):
                bl = False
        if(bl):
            uniq2.append(i)
            
    uniq1 = np.sort(uniq1)
    uniq2 = np.sort(uniq2)
    
    table_pirs = pd.DataFrame({               #Таблица частот, для заданных данных
        (uniq2[0]):[0 for i in range(len(uniq1))],
        (uniq2[1]):[0 for i in range(len(uniq1))]
    }, index = uniq1);
    
    table_pirs.index.name = data.columns[0]
    
    #print(table_pirs['no'])
    for i in range(len(data)):                #частоты совпадений группы и признака
        table_pirs[data.iloc[i,1]][data.iloc[i,0]] += 1
        
    print("Початкова таблиця спряженості:")
    print(table_pirs)
    
    if (sum(table_pirs.iloc[:,0]) != sum(table_pirs.iloc[:,1])):
        table_pirs[table_pirs.columns[1]] = [
            x/sum(table_pirs.iloc[:,1])*sum(table_pirs.iloc[:,0]) # перерасчет конкретной(x-вого рядка) частоты
            for x in table_pirs.iloc[:,1] # Проход по всем частотом группы
        ]
    table_pirs['(ni-ni`)'] = [(table_pirs.iloc[i,0] - table_pirs.iloc[i,1]) for i in range(len(table_pirs))]
    table_pirs['(ni-ni`)^2/ni`'] = [(table_pirs.iloc[i,2]**2/table_pirs.iloc[i,1]) for i in range(len(table_pirs))]
    print("\nКінцева таблиця спряженості:")
    print(table_pirs)
    
    chi2 =  sum(table_pirs.iloc[:,3])
    print("\nX^2(емпіричне) - " + str(chi2))
    
    r = len(table_pirs)-1
    print("ступінь свободи - " + str(r))
    
    crit_pirson = pd.read_excel("table_Pirson.xlsx").iloc[r, 1 if(significant_level == 0.01) else 2]
    print("X^2(табличне) - " + str(crit_pirson))
    print("-"*40)
    
    return "Статистична розбіжність відсутня або не суттєва %.2f(эмп)"%chi2 +" < " "%.1f(табл)"%crit_pirson  if (chi2 < crit_pirson) else"Статистичная розбіжність присутня %.2f(емп)"%chi2 +" > " "%.1f(табл)"%crit_pirson

# %%
print("Результат роботи - " + str(pirson_criterion(data,0.01)))
# Out:
# ----------------------------------------
# Робота функції
# Початкова таблиця спряженості:
#        A    T
# Dalc
# 1     29  247
# 2      5   70
# 3      4   22
# 4      2    7
# 5      1    8
#
# Кінцева таблиця спряженості:
#        A          T  (ni-ni`)  (ni-ni`)^2/ni`
# Dalc
# 1     29  28.607345  0.392655        0.005389
# 2      5   8.107345 -3.107345        1.190968
# 3      4   2.548023  1.451977        0.827402
# 4      2   0.810734  1.189266        1.744532
# 5      1   0.926554  0.073446        0.005822
#
# X^2(емпіричне) - 3.774113883549057
# ступінь свободи - 4
# X^2(табличне) - 13.3
# ----------------------------------------
# Результат роботи - Статистична розбіжність відсутня або не суттєва 3.77(эмп) < 13.3(табл)

# %% [markdown]
# <p style="color:#4ca8ed;font-size:150%">
#    4. Перевірити розбіжність на між групами на даних з п. 1. В результаті сформувати таблицю спряженості.Додати до таблиці стовбчики з відсотовим розподілом по градаціям всередині груп.
# </p>

# %%
table_pirs = pd.DataFrame(
    {
        'A': [0 for i in range(5)],
        'T': [0 for i in range(5)],
        '%A': [0 for i in range(5)],
        '%T': [0 for i in range(5)]
    }, index = [1,2,3,4,5])
table_pirs.index.name = "Dalc"

for i in range(len(data)):           #частоты совпадений группы и признака
    table_pirs[data['Pstatus'][i]][data['Dalc'][i]] += 1
    
for i in range(1,len(table_pirs)+1): #процентные соотношения в групах
    table_pirs.loc[i,"%A"] = str(round(table_pirs["A"][i]/sum(table_pirs["A"])*100,1))+ "%"
    table_pirs.loc[i,"%T"] = str(round(table_pirs["T"][i]/sum(table_pirs["T"])*100,1))+ "%"
    
table_pirs
# Out:
#        A    T     %A     %T
# Dalc
# 1     29  247  70.7%  69.8%
# 2      5   70  12.2%  19.8%
# 3      4   22   9.8%   6.2%
# 4      2    7   4.9%   2.0%
# 5      1    8   2.4%   2.3%

# %%
x = np.arange(len(table_pirs))
width = 0.35

y = [ i*10 for i in np.linspace(0,26,14)]

fig, ax = plt.subplots(figsize=(10,10))
fig.height = 10
rects1 = ax.bar(x - width/2, table_pirs["A"], width, label='A')
rects2 = ax.bar(x + width/2, table_pirs["T"], width, label='T')

ax.set_ylabel('Кількість')
ax.set_xlabel('Ступінь вживання алкоголю')
ax.set_title('розподіл ознаки по групам')
ax.set_xticks(x)
ax.set_yticks(y)

ax.legend()
ax.grid()

fig.tight_layout()

plt.show()
