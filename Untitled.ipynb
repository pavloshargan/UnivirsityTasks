# %%
import instagram_explore as ie

# Search tag name
res = ie.tag('cat')
print(res.data)

# Next page
data, cursor = ie.tag('cat', res.cursor)

# Image only
images = ie.tag_images('cat').data
# Out:
# {'id': '17841562906103814', 'name': 'cat', 'allow_following': False, 'description': '', 'is_following': False, 'is_top_media_only': False, 'profile_pic_url': 'https://instagram.fdnk1-1.fna.fbcdn.net/v/t51.2885-15/e35/c239.0.961.961a/s150x150/90735718_560023924865448_769075767636566057_n.jpg?_nc_ht=instagram.fdnk1-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=kvCWphky1lIAX_TdgYx&oh=9bdcd1e6f80651c9e78ede7eb20d9c3c&oe=5EB24B90', 'edge_hashtag_to_media': {'count': 201244164, 'page_info': {'has_next_page': True, 'end_cursor': 'QVFCeVlFbmlLT2xGbFl5aFJuMzdfX3FWMkFFSWhITnVzRWVoSTBDQjExQlhtczMzRjNQRlYxMzMwcFh2Tm8wUmc4R1lPY0U2aTZad1otQmxCa2VHeE5YRg=='}, 'edges': [{'node': {'comments_disabled': False, '__typename': 'GraphImage', 'id': '2270465834281722471', 'edge_media_to_caption': {'edges': [{'node': {'text': '#life#beautyful#nice#sun#summer#spring#lifestyle#fruit#city#cat#dog#nature'}}]}, 'shortcode': 'B-CUKWXBeJn', 'edge_media_to_comment': {'count': 0}, 'taken_at_timestamp': 1584880640, 'dimensions': {
# ...
